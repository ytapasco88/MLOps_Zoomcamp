# %%
import pandas as pd
import os
import mlflow

from IPython.display import Image

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("random-forest-hyperopt")
# Out:
# 2024/05/27 12:29:15 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2024/05/27 12:29:15 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# ...

# %%
current_directory = os.getcwd()
started_directory = os.path.dirname(current_directory)

# %%
current_directory
# Out:
# 'c:\\Users\\ytapa\\OneDrive\\Learning\\MLOps_Zoomcamp\\02-experiment-tracking\\homework'

# %% [markdown]
# After, in command line run:
#
# * cd <current_directory>
# * mlflow ui --backend-store-uri sqlite:///mlflow.db

# %% [markdown]
# ### Q1. Install MLflow
#
# **Once you installed the package, run the command mlflow --version and check the output.**
#
# **What's the version that you have?**

# %%
# !mlflow --version
# Out:
# mlflow, version 2.13.0

# %% [markdown]
# ### Q2. Download and preprocess the data

# %%
import preprocess_data

# %%
TAXI_DATA_FOLDER = current_directory + "\\data\\"
TAXI_DATA_FOLDER
# Out:
# 'c:\\Users\\ytapa\\OneDrive\\Learning\\MLOps_Zoomcamp\\02-experiment-tracking\\homework\\data\\'

# %% [markdown]
# **Tip: go to 02-experiment-tracking/homework/ folder before executing the command and change the value of <TAXI_DATA_FOLDER> to the location where you saved the data.**

# %%
# !python preprocess_data.py --raw_data_path c:\\Users\\ytapa\\OneDrive\\Learning\\MLOps_Zoomcamp\\02-experiment-tracking\\homework\\data\\ --dest_path ./output

# %% [markdown]
# **¿How many files were saved to OUTPUT_FOLDER?**
#
# Answer: 4

# %%
# !dir c:\Users\ytapa\OneDrive\Learning\MLOps_Zoomcamp\02-experiment-tracking\homework\output /s
# Out:
#  El volumen de la unidad C es OS
#  El n�mero de serie del volumen es: 7A39-5842
#
#  Directorio de c:\Users\ytapa\OneDrive\Learning\MLOps_Zoomcamp\02-experiment-tracking\homework\output
#
# 27/05/2024  12:30 p.�m.    <DIR>          .
# 27/05/2024  12:30 p.�m.    <DIR>          ..
# 27/05/2024  12:30 p.�m.           131.004 dv.pkl
# 27/05/2024  12:30 p.�m.         2.458.697 test.pkl
# 27/05/2024  12:30 p.�m.         2.374.517 train.pkl
# 27/05/2024  12:30 p.�m.         2.215.823 val.pkl
#                4 archivos      7.180.041 bytes
#
#      Total de archivos en la lista:
#                4 archivos      7.180.041 bytes
#                2 dirs  275.610.791.936 bytes libres

# %% [markdown]
# ### Q3. Train a model with autolog
#
# **¿What is the value of the min_samples_split parameter?**
#
# Answer: 2

# %%
Image(filename= current_directory + "\\images\\" + "Q3_Train_Autolog.png")

# %% [markdown]
# ### Q5. Tune model hyperparameters
#
# **What's the best validation RMSE that you got?**
#
# Answer: 5.335

# %% [markdown]
# ### Q4. Launch the tracking server locally

# %%
Image(filename= current_directory + "\\images\\" + "Q5 Tune model hyperparameters.png")

# %% [markdown]
# ### Q6. Promote the best model to the model registry
#
# **What is the test RMSE of the best model?**
#
# Answer: 5.567

# %%
Image(filename= current_directory + "\\images\\" + "Q6 Promote the best model to the model registry.png")
